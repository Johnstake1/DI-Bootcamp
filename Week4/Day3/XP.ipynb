# %% [markdown]
# Exercise 1 - Identifying Data Types:
#
# A company's financial reports stored in excel is a structured data.
#
# Photographs uploaded to a social media platform is unstructured data.
#
# A collection of news articles on a website is unstructured data.
#
# Inventroy data in a RDBSM is structured data.
#
# Recorded interview is not structured data.

# %% [markdown]
# Exercise 2: Transformation Exercise
#
# A series of blog posts about travel experiences:
#
# You should create some categories such as countries, cities or themes, have the dates aligned correctly to be able to manipulate the data.
#
#
# Audio recordings of customer service calls:
#
# We should try to track the following:
#
# *   date of call
# *   topic
# *   customer
# *   agent/rep
# *   duration of calls.
#
# Handwritten notes from a brainstorming session:
#
# *   ideas
# *   names of participants
# *   industries affected
#
# A video tutorial on cooking.
#
#
# *   utensils
# *   recipes
# *   type of food
# *   dietary needs

# %%
#Exercise 3 - Import Titanic from Kaggle

import pandas as pd

url = 'insert link here'

titanic_dataset = pd.read_csv(url)

#could not find a direct link for a csv file in kagle. but that should be the way

titanic_dataset.head()

# %%
#Exercise 4 - Import the Iris CSV file
import pandas as pd

iris_dataset = pd.read_csv('/content/Iris.csv')

iris_dataset.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#Exercise 5 - Export a dataframe to excel format and JSON format.

import pandas as pd

data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [24, 27, 22],
    'City': ['New York', 'Los Angeles', 'Chicago']
}

df = pd.DataFrame(data)
df.to_excel('data.xlsx', index=False)

# %%
df.to_json('data.json', orient='records')

# %%
 #Exercise 6: Reading JSON Data

 import pandas as pd

 df = pd.read_json('/content/posts.json')

 df.head()
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...
