# %% [markdown]
# #EX1 What is data analysis and why is important?
# data analysis is the method or the way in charge of answering questions that companies or individuals may have in order to make decisions.
# It is one of the most important factors in decision making.
#  List and describe three areas where data analysis is applied today?
#  1. Sports - uses data analytics to check where players move in the field (futbol) to plan games
#  2. Finance - is used by quant finance to generate alpha
#  3. Digital Marketing is used to optimize targeted audiences or explore new markets"

# %%
import pandas as pd

df = pd.read_csv('/content/clean_dataset.csv')
df.head()
# Out:
#    Gender    Age   Debt  Married  BankCustomer     Industry Ethnicity  \
# 0       1  30.83  0.000        1             1  Industrials     White
# 1       0  58.67  4.460        1             1    Materials     Black
# 2       0  24.50  0.500        1             1    Materials     Black
# 3       1  27.83  1.540        1             1  Industrials     White
# 4       1  20.17  5.625        1             1  Industrials     White
#
#    YearsEmployed  PriorDefault  Employed  CreditScore  DriversLicense  \
# 0           1.25             1         1            1               0
# 1           3.04             1         1            6               0
# 2           1.50             1         0            0               0
# 3           3.75             1         1            5               1
# 4           1.71             1         0            0               0
#
#         Citizen  ZipCode  Income  Approved
# 0       ByBirth      202       0         1
# ...

# %%
df.describe()
# Out:
#            Gender         Age        Debt     Married  BankCustomer  \
# count  690.000000  690.000000  690.000000  690.000000    690.000000
# mean     0.695652   31.514116    4.758725    0.760870      0.763768
# std      0.460464   11.860245    4.978163    0.426862      0.425074
# min      0.000000   13.750000    0.000000    0.000000      0.000000
# 25%      0.000000   22.670000    1.000000    1.000000      1.000000
# 50%      1.000000   28.460000    2.750000    1.000000      1.000000
# 75%      1.000000   37.707500    7.207500    1.000000      1.000000
# max      1.000000   80.250000   28.000000    1.000000      1.000000
#
#        YearsEmployed  PriorDefault    Employed  CreditScore  DriversLicense  \
# count     690.000000    690.000000  690.000000    690.00000      690.000000
# mean        2.223406      0.523188    0.427536      2.40000        0.457971
# std         3.346513      0.499824    0.495080      4.86294        0.498592
# ...

# %%
df1 = pd.read_csv('/content/Time Americans Spend Sleeping.csv')
df1.head()
# Out:
#    index  Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# 0      0  2003  Annual                      8.57           0.018     All days
# 1      1  2004  Annual                      8.55           0.026     All days
# 2      2  2005  Annual                      8.62           0.023     All days
# 3      3  2006  Annual                      8.63           0.024     All days
# 4      4  2007  Annual                      8.57           0.024     All days
#
#            Age Group  Activity   Sex
# 0  15 years and over  Sleeping  Both
# 1  15 years and over  Sleeping  Both
# 2  15 years and over  Sleeping  Both
# 3  15 years and over  Sleeping  Both
# 4  15 years and over  Sleeping  Both

# %%
df1.describe()
# Out:
#             index         Year  Avg hrs per day sleeping  Standard Error
# count  945.000000   945.000000                945.000000      945.000000
# mean   472.000000  2010.000000                  8.806868        0.086958
# std    272.942302     4.322782                  0.545001        0.034631
# min      0.000000  2003.000000                  7.720000        0.018000
# 25%    236.000000  2006.000000                  8.360000        0.063000
# 50%    472.000000  2010.000000                  8.810000        0.084000
# 75%    708.000000  2014.000000                  9.190000        0.106000
# max    944.000000  2017.000000                 10.650000        0.228000

# %%
df2 = pd.read_csv('/content/Mental health Depression disorder Data.csv')
df2.head()
# Out:
# <ipython-input-12-242098533595>:1: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('/content/Mental health Depression disorder Data.csv')
#    index       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 0      0  Afghanistan  AFG  1990           0.16056             0.697779
# 1      1  Afghanistan  AFG  1991          0.160312             0.697961
# 2      2  Afghanistan  AFG  1992          0.160135             0.698107
# 3      3  Afghanistan  AFG  1993          0.160037             0.698257
# 4      4  Afghanistan  AFG  1994          0.160022             0.698469
#
#   Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 0             0.101855               4.828830                1.677082
# 1             0.099313               4.829740                1.684746
# 2             0.096692               4.831108                1.694334
# ...

# %%
df2.describe()
# Out:
#                index  Anxiety disorders (%)  Drug use disorders (%)  \
# count  108553.000000            6468.000000             6468.000000
# mean    54276.000000               3.989921                0.862278
# std     31336.696223               1.167526                0.460679
# min         0.000000               2.023393                0.383650
# 25%     27138.000000               3.188824                0.535064
# 50%     54276.000000               3.554373                0.726430
# 75%     81414.000000               4.682163                0.940157
# max    108552.000000               8.967330                3.452476
#
#        Depression (%)  Alcohol use disorders (%)
# count     6468.000000                6468.000000
# mean         3.497654                   1.585821
# std          0.655859                   0.860283
# min          2.139903                   0.446940
# 25%          3.005529                   0.993685
# 50%          3.499606                   1.479936
# ...

# %%
df.select_dtypes(include=['int64', 'float64']) #All data has been set to quant (integers and floats), even though there are categories that are qualitative (mainly set YES = 1 and NO = 0)
# Out:
#      Gender    Age    Debt  Married  BankCustomer  YearsEmployed  \
# 0         1  30.83   0.000        1             1           1.25
# 1         0  58.67   4.460        1             1           3.04
# 2         0  24.50   0.500        1             1           1.50
# 3         1  27.83   1.540        1             1           3.75
# 4         1  20.17   5.625        1             1           1.71
# ..      ...    ...     ...      ...           ...            ...
# 685       1  21.08  10.085        0             0           1.25
# 686       0  22.67   0.750        1             1           2.00
# 687       0  25.25  13.500        0             0           2.00
# 688       1  17.92   0.205        1             1           0.04
# 689       1  35.00   3.375        1             1           8.29
#
#      PriorDefault  Employed  CreditScore  DriversLicense  ZipCode  Income  \
# 0               1         1            1               0      202       0
# ...

# %%
df1.select_dtypes(include=['int64', 'float64']) # All categories are quant
# Out:
#      index  Year  Avg hrs per day sleeping  Standard Error
# 0        0  2003                      8.57           0.018
# 1        1  2004                      8.55           0.026
# 2        2  2005                      8.62           0.023
# 3        3  2006                      8.63           0.024
# 4        4  2007                      8.57           0.024
# ..     ...   ...                       ...             ...
# 940    940  2013                      8.83           0.085
# 941    941  2014                      8.98           0.086
# 942    942  2015                      8.83           0.074
# 943    943  2016                      8.92           0.071
# 944    944  2017                      8.81           0.091
#
# [945 rows x 4 columns]

# %%
df2.select_dtypes(include=['int64', 'float64']) #all categories are quant
# Out:
#          index  Anxiety disorders (%)  Drug use disorders (%)  Depression (%)  \
# 0            0               4.828830                1.677082        4.071831
# 1            1               4.829740                1.684746        4.079531
# 2            2               4.831108                1.694334        4.088358
# 3            3               4.830864                1.705320        4.096190
# 4            4               4.829423                1.716069        4.099582
# ...        ...                    ...                     ...             ...
# 108548  108548                    NaN                     NaN             NaN
# 108549  108549                    NaN                     NaN             NaN
# 108550  108550                    NaN                     NaN             NaN
# 108551  108551                    NaN                     NaN             NaN
# 108552  108552                    NaN                     NaN             NaN
#
# ...

# %%
df3 = pd.read_csv('/content/Iris.csv')
df3.head()

#Qualit = Species
#Quant - The remaining
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#EX5
df3.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
import matplotlib.pyplot as plt
plt.hist(df3['SepalLengthCm'])
plt.show()

#The graph will show the frequencies of the Sepal Length. We can see that the majority of times the sepals were 5.5 and 6.5 cm long (occurance of 25 times)

# %%
#EX6

df1.head() #You can create a trend of avg sleeping hours over the years depending the category Types of days or by Age group. You can play within the Sex categories too
# Out:
#    index  Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# 0      0  2003  Annual                      8.57           0.018     All days
# 1      1  2004  Annual                      8.55           0.026     All days
# 2      2  2005  Annual                      8.62           0.023     All days
# 3      3  2006  Annual                      8.63           0.024     All days
# 4      4  2007  Annual                      8.57           0.024     All days
#
#            Age Group  Activity   Sex
# 0  15 years and over  Sleeping  Both
# 1  15 years and over  Sleeping  Both
# 2  15 years and over  Sleeping  Both
# 3  15 years and over  Sleeping  Both
# 4  15 years and over  Sleeping  Both

# %%
df1.tail()
# Out:
#      index  Year  Period  Avg hrs per day sleeping  Standard Error  \
# 940    940  2013  Annual                      8.83           0.085
# 941    941  2014  Annual                      8.98           0.086
# 942    942  2015  Annual                      8.83           0.074
# 943    943  2016  Annual                      8.92           0.071
# 944    944  2017  Annual                      8.81           0.091
#
#             Type of Days          Age Group  Activity    Sex
# 940  Nonholiday weekdays  65 years and over  Sleeping  Women
# 941  Nonholiday weekdays  65 years and over  Sleeping  Women
# 942  Nonholiday weekdays  65 years and over  Sleeping  Women
# 943  Nonholiday weekdays  65 years and over  Sleeping  Women
# 944  Nonholiday weekdays  65 years and over  Sleeping  Women
