# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

cities = ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix', 'Philadelphia', 'San Antonio', 'San Diego', 'Dallas', 'San Jose']
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

temperature = np.random.uniform(-5,35, (10,12))

df=pd.DataFrame(temperature, index=cities, columns=months)
df
# Out:
#                 January   February      March      April        May  \
# New York      -0.852505  10.764164   3.563260  20.203482  -2.294312
# Los Angeles   16.436444  10.341979  28.103657  10.759103  10.843241
# Chicago       15.357377  29.004608  13.434139  31.048079   9.980935
# Houston       -4.606819  15.913040  22.404697  24.474324  14.794456
# Phoenix       34.348443  27.184854   9.464212  32.444379  29.630295
# Philadelphia   2.163877  15.582945  16.051424  24.733818  10.925315
# San Antonio   18.629475  11.495299   0.838075   8.933657   6.625052
# San Diego     -4.469419  27.411523  -4.803057  11.634363  23.910360
# Dallas        29.592788  24.640820  29.141541  30.498946  15.474678
# San Jose      27.442921  27.982687  32.324333  -4.676578  13.175704
#
#                    June       July     August  September    October  \
# New York      17.947502  34.201794  21.917154   9.822024  25.356967
# Los Angeles   14.220140   8.833834   9.495798  -1.315267  32.753296
# ...

# %%
#Calculate the annual average temperature for each city
annual_avg = df.mean(axis=1)
annual_avg

#Identify the city with the highest and lowest average temperature for the year

highest_avg = annual_avg.idxmax()
print(f'The city with the highest average temperature is {highest_avg}')

lowest_avg = annual_avg.idxmin()
print(f'The city with the lowest average temperature is {lowest_avg}')
# Out:
# The city with the highest average temperature is Chicago
# The city with the lowest average temperature is San Diego

# %%
# Plot the temperatures for each city across the months
plt.figure(figsize=(12, 8))
for city in cities:
    plt.plot(months, df.loc[city], label=city) #it will loop through each city and plot the temperature for the respective month

plt.xlabel('Months')
plt.ylabel('Temperature (°C)')
plt.title('Monthly Temperatures for Each City')
plt.legend(loc='lower left')
plt.grid(True)
plt.show()
