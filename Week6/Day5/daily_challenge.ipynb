# %% [markdown]
# 1. Data Loading and Exploration:

# %%
import pandas as pd
import numpy as np

train = pd.read_csv('train.csv')

train.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
train.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
train.drop_duplicates(inplace=True)
train.info()

#Conclustion
#no missing values nor duplicated rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
train.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %% [markdown]
# 2. Data Cleaning and Preprocessing:

# %%
#It looks like the data has been already preprocesed, since there are no missing values, no duplicated rows and all the category columns were transformed to numerical

train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
#Calculation of mean, mode, median and standard deviation for each column

train.mean()
# Out:
# battery_power    1238.51850
# blue                0.49500
# clock_speed         1.52225
# dual_sim            0.50950
# fc                  4.30950
# four_g              0.52150
# int_memory         32.04650
# m_dep               0.50175
# mobile_wt         140.24900
# n_cores             4.52050
# pc                  9.91650
# px_height         645.10800
# px_width         1251.51550
# ram              2124.21300
# sc_h               12.30650
# sc_w                5.76700
# talk_time          11.01100
# three_g             0.76150
# touch_screen        0.50300
# wifi                0.50700
# price_range         1.50000
# dtype: float64

# %%
train.mode().dropna()
# Out:
#    battery_power  blue  clock_speed  dual_sim   fc  four_g  int_memory  m_dep  \
# 0          618.0   0.0          0.5       1.0  0.0     1.0        27.0    0.1
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0      182.0      4.0  ...      347.0     874.0  1229  17.0   1.0        7.0
#
#    three_g  touch_screen  wifi  price_range
# 0      1.0           1.0   1.0          0.0
#
# [1 rows x 21 columns]

# %%
train.median()
# Out:
# battery_power    1226.0
# blue                0.0
# clock_speed         1.5
# dual_sim            1.0
# fc                  3.0
# four_g              1.0
# int_memory         32.0
# m_dep               0.5
# mobile_wt         141.0
# n_cores             4.0
# pc                 10.0
# px_height         564.0
# px_width         1247.0
# ram              2146.5
# sc_h               12.0
# sc_w                5.0
# talk_time          11.0
# three_g             1.0
# touch_screen        1.0
# wifi                1.0
# price_range         1.5
# dtype: float64

# %%
train.std()
# Out:
# battery_power     439.418206
# blue                0.500100
# clock_speed         0.816004
# dual_sim            0.500035
# fc                  4.341444
# four_g              0.499662
# int_memory         18.145715
# m_dep               0.288416
# mobile_wt          35.399655
# n_cores             2.287837
# pc                  6.064315
# px_height         443.780811
# px_width          432.199447
# ram              1084.732044
# sc_h                4.213245
# sc_w                4.356398
# talk_time           5.463955
# three_g             0.426273
# touch_screen        0.500116
# wifi                0.500076
# price_range         1.118314
# dtype: float64

# %%
train.var()
# Out:
# battery_power    1.930884e+05
# blue             2.501001e-01
# clock_speed      6.658629e-01
# dual_sim         2.500348e-01
# fc               1.884813e+01
# four_g           2.496626e-01
# int_memory       3.292670e+02
# m_dep            8.318353e-02
# mobile_wt        1.253136e+03
# n_cores          5.234197e+00
# pc               3.677592e+01
# px_height        1.969414e+05
# px_width         1.867964e+05
# ram              1.176644e+06
# sc_h             1.775143e+01
# sc_w             1.897820e+01
# talk_time        2.985481e+01
# three_g          1.817086e-01
# touch_screen     2.501161e-01
# wifi             2.500760e-01
# price_range      1.250625e+00
# dtype: float64

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from scipy.stats import kurtosis, skew

kurtosis_mobile_phone_battery_power = kurtosis(train['battery_power'])

skew_mobile_phone_battery_power = skew(train['battery_power'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 from scipy.stats import kurtosis, skew
# ----> 3 kurtosis_mobile_phone_battery_power = kurtosis(train['battery_power'])
#       5 skew_mobile_phone_battery_power = skew(train['battery_power'])
#
# NameError: name 'train' is not defined

# %%
pip list
# Out:
# Package                   VersionNote: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ------------------------- -----------
# asttokens                 2.4.1
# attrs                     24.2.0
# beautifulsoup4            4.12.3
# certifi                   2024.8.30
# charset-normalizer        3.4.0
# colorama                  0.4.6
# comm                      0.2.2
# contourpy                 1.3.1
# cycler                    0.12.1
# DateTime                  5.5
# debugpy                   1.8.9
# decorator                 5.1.1
# executing                 2.1.0
# fastjsonschema            2.21.1
# fonttools                 4.55.0
# frozendict                2.4.6
# html5lib                  1.1
# idna                      3.10
# ipykernel                 6.29.5
# ipython                   8.29.0
# jedi                      0.19.2
# ...
