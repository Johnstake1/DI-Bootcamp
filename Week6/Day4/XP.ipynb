# %%
#🌟 Exercise 1 : Linear Regression Analysis
import numpy as np
from scipy import stats

house_prices = [150000, 200000, 210000, 250000, 280000]
house_sizes = [50, 70, 80, 100, 120]

slope, intercept, r_value, p_value, std_err = stats.linregress(house_sizes, house_prices)

print(f'The slope is {slope.round(2)} and the intercept is {intercept.round(2)}')

house_size_new = 90
predicted_price = slope * house_size_new + intercept
print(f'The predicted price for a house of size {house_size_new} square meters is ${predicted_price.round(2)}')

#In the case of the slope for this exercise, it measures the increase in house price for every additional square meter of the house size.
# Out:
# The slope is 1828.77 and the intercept is 64383.56
# The predicted price for a house of size 90 square meters is $228972.6

# %%
#🌟 Exercise 2 : Understanding ANOVA
from scipy.stats import f_oneway

f1 = [5, 6, 7, 6, 5]
f2 = [7, 8, 7, 9, 8]
f3 = [4, 5, 4, 3, 4]

f_value, p_value = f_oneway(f1, f2, f3)

print(f'The F-value is {f_value} and the p-value is {p_value}')

if p_value < 0.05:
    print('There is a significant difference between the fertilizers of the three groups')
else:
    print('There is no significant difference between the fertilizers of the three groups')

#If p-value is bigger than 0.05, we can't reject the null hypothesis, which means that there is no significant difference between the fertilizers of the three groups.
# Out:
# The F-value is 28.52631578947368 and the p-value is 2.7542672098048448e-05
# There is a significant difference between the fertilizers of the three groups

# %%
#🌟 Exercise 3 : Probability Distributions

coin_flips, p = 10, 0.5

binomial_distribution = stats.binom(coin_flips, p)

print(f'The probability of getting 10 heads, when flipping a coin 10 times, is {binomial_distribution.pmf(5)}')
# Out:
# The probability of getting 10 heads, when flipping a coin 10 times, is 0.24609375

# %%
#🌟 Exercise 4 : Correlation Coefficients
import pandas as pd
from scipy.stats import spearmanr

data = pd.DataFrame({'age': [23, 25, 30, 35, 40], 
                     'income': [35000, 40000, 50000, 60000, 70000]})

correlation, p_value = spearmanr(data['age'], data['income'])

print(f'The correlation coefficient is {correlation}.')
# Out:
# The correlation coefficient is 0.9999999999999999.

# %%
#🌟 Exercise 5 : Linear Relationships
import matplotlib.pyplot as plt
data = pd.DataFrame({'age': [23, 25, 30, 35, 40], 
                     'income': [35000, 40000, 50000, 60000, 70000]})

plt.scatter(data['age'], data['income'], color='blue', label='Data points')
plt.xlabel('Age')
plt.ylabel('Income')
plt.title('Income vs Age')
plt.legend()
plt.show()

#conclusion:

#As the previous exercise shows, there is a positive relationship between age and income.
#This means that as age increases, income also increases.
